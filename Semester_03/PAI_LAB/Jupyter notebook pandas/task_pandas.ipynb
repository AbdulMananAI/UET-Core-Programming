# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(columns=['Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop(columns=['Cabin'])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna('S')
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
med_age = df['Age'].median()  
df['Age'] = df['Age'].fillna(med_age) 
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
pass_cls1_surv = df[(df['Pclass'] == 1) & (df['Survived'] == 1)]
pass_cls1_surv.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 23           24         1       1
# 31           32         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  28.0      1
#
#     Parch    Ticket      Fare Embarked
# 1       0  PC 17599   71.2833        C
# 3       0    113803   53.1000        S
# 11      0    113783   26.5500        S
# 23      0    113788   35.5000        S
# 31      0  PC 17569  146.5208        C

# %%
df['FamilyTotal'] = df['SibSp'] + df['Parch']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  FamilyTotal
# 0      0         A/5 21171   7.2500        S            1
# 1      0          PC 17599  71.2833        C            1
# 2      0  STON/O2. 3101282   7.9250        S            0
# 3      0            113803  53.1000        S            1
# 4      0            373450   8.0500        S            0

# %%
mask = df['FamilyTotal'] >= 4
df[mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# 25            26         1       3
# ..           ...       ...     ...
# 824          825         0       3
# 846          847         0       3
# 850          851         0       3
# 863          864         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# 824                       Panula, Master. Urho Abraham    male   2.0      4
# 846                           Sage, Mr. Douglas Bullen    male  28.0      8
# 850            Andersson, Master. Sigvard Harald Elias    male   4.0      4
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  28.0      8
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch    Ticket     Fare Embarked  FamilyTotal
# 7        1    349909  21.0750        S            4
# 13       5    347082  31.2750        S            6
# 16       1    382652  29.1250        Q            5
# 24       1    349909  21.0750        S            4
# 25       5    347077  31.3875        S            6
# ..     ...       ...      ...      ...          ...
# 824      1   3101295  39.6875        S            5
# 846      2  CA. 2343  69.5500        S           10
# 850      2    347082  31.2750        S            6
# 863      2  CA. 2343  69.5500        S           10
# 885      5    382652  29.1250        Q            5
#
# [62 rows x 12 columns]

# %%
Dr_passengers = df[df['Name'].str.contains('Dr.', na=False)]

Dr_passengers.head()
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 47            48         1       3    O'Driscoll, Miss. Bridget  female  28.0
# 130          131         0       3         Drazenoic, Mr. Jozef    male  33.0
# 245          246         0       1  Minahan, Dr. William Edward    male  44.0
# 317          318         0       2         Moraweck, Dr. Ernest    male  54.0
# 398          399         0       2             Pain, Dr. Alfred    male  23.0
#
#      SibSp  Parch  Ticket     Fare Embarked  FamilyTotal
# 47       0      0   14311   7.7500        Q            0
# 130      0      0  349241   7.8958        C            0
# 245      2      0   19928  90.0000        Q            2
# 317      0      0   29011  14.0000        S            0
# 398      0      0  244278  10.5000        S            0

# %%
Dr_passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 47 to 796
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  11 non-null     int64
#  1   Survived     11 non-null     int64
#  2   Pclass       11 non-null     int64
#  3   Name         11 non-null     object
#  4   Sex          11 non-null     object
#  5   Age          11 non-null     float64
#  6   SibSp        11 non-null     int64
#  7   Parch        11 non-null     int64
#  8   Ticket       11 non-null     object
#  9   Fare         11 non-null     float64
#  10  Embarked     11 non-null     object
#  11  FamilyTotal  11 non-null     int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 1.1+ KB
